# %% [markdown]
# # Unit 2 texts:
#  [main text](../unit2/unit2.pdf)
#  [task code](../unit2/unit2_code.pdf)
#  [production summary](../unit2/productions-summary.pdf)

# %% [markdown]
# # Run the ACT-R tutorial unit 2 models in Python

# %% [markdown]
# ## Demo2 model and task

# %% [markdown]
# The model file for this task is [demo2-model.lisp](../unit2/demo2-model.lisp).

# %% [markdown]
# Run this cell to connect to ACT-R and load the [demo2 task](demo2.py) and model.

# %%
import actr
import demo2

# %% [markdown]
# Run this cell to do the task yourself.  You must have either the Control Panel or the HTML Experiment viewer open to do so.

# %%
demo2.experiment(True)

# %% [markdown]
# Run this cell to run the model in the task.

# %%
demo2.experiment()

# %% [markdown]
# ## Unit2 model and task

# %% [markdown]
# The model file for this task is [unit2-assignment-model.lisp](../unit2/unit2-assignment-model.lisp).
# You will need to write the productions for the model to be able to perform the task.

# %% [markdown]
# Run this cell to connect to ACT-R and load the [unit2 task](unit2.py) and model.

# %%
import actr
import unit2

# %% [markdown]
# When you change the model file you will need to either run this cell to reload the model or press the Reload button on the Control Panel to have the updated model loaded into ACT-R.

# %%
actr.reload()

# %% [markdown]
# Run this cell to perform the task yourself.  You must have an Experiment window viewer open to do so.

# %%
unit2.experiment(True)

# %% [markdown]
# Run this cell to have the model perform the task.
# If the return value is True then it has completed the task correctly.

# %%
unit2.experiment()
