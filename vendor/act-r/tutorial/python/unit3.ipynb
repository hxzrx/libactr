# %% [markdown]
# # Unit 3 texts:
#  [main text](../unit3/unit3.pdf)
#  [task code](../unit3/unit3_code.pdf)
#  [additional modeling information](../unit3/unit3_modeling.pdf)
#  [production summary](../unit3/productions-summary.pdf)

# %% [markdown]
# # Run the ACT-R tutorial unit 3 models in Python

# %% [markdown]
# If you change a model file then you can run this cell to reload the current model or press the Reload button in the ACT-R Environment GUI to have the updated model loaded into ACT-R.

# %%
actr.reload()

# %% [markdown]
# ## Sperling demo model and task

# %% [markdown]
# The model file for this task is [sperling-model.lisp](../unit3/sperling-model.lisp).

# %% [markdown]
# Run this cell to connect to ACT-R and load the [sperling task](sperling.py) and the model.

# %%
import actr
import sperling

# %% [markdown]
# Run this cell to have the model perform one trial of the task specifying the delay time.

# %%
sperling.trial(.15)

# %% [markdown]
# Run this cell to have the model perform the whole experiment the provided number of times.
# You should edit the model file to turn off the trace and then reload it before running the whole experiment to avoid a long delay and an excesive amount of trace information.

# %%
sperling.experiment(1)

# %% [markdown]
# ## Subitizing assignment model and task

# %% [markdown]
# The model file for this task is [subitizing-model.lisp](../unit3/subitize-model.lisp).

# %% [markdown]
# Run this cell to connect to ACT-R and load the [subitize task](subitize.py) and model.

# %%
import actr
import subitize

# %% [markdown]
# Run this cell to perform one trial of the task yourself with the indicated number of items.

# %%
subitize.trial(3,True)

# %% [markdown]
# Run this cell to go through the whole experiment yourself.

# %%
subitize.experiment(True)

# %% [markdown]
# Run this cell to run the model through one trial with the indicated number of items.

# %%
subitize.trial(2)

# %% [markdown]
# Run this cell to run the model through the whole experiment and report the results.
# Here are the results from a good solution for this task.  The most important thing for your model is that it has (True ) for all entries in the "Current Participant" column indicating that it got the answer correct.
#
# CORRELATION: 0.980
# MEAN DEVIATION: 0.230
# |Items|    Current Participant|     Original Experiment |
# |---|---|---|
# | 1 |        0.54 (True )    |              0.60  |
# | 2 |        0.77 (True )    |              0.65  |
# | 3 |        1.00 (True )    |              0.70  |
# | 4 |        1.24 (True )    |              0.86  |
# | 5 |        1.48 (True )    |              1.12  |
# | 6 |        1.71 (True )    |              1.50  |
# | 7 |        1.95 (True )    |              1.79  |
# | 8 |        2.18 (True )    |              2.13  |
# | 9 |        2.41 (True )    |              2.15  |
# |10 |        2.65 (True )    |              2.58  |

# %%
subitize.experiment()

# %% [markdown]
# ## Model debugging from the unit 3 modeling text

# %% [markdown]
# The model file for this task is [perceptual-motor-issues-model.lisp](../unit3/perceptual-motor-issues-model.lisp).

# %% [markdown]
# Run this cell to connect to ACT-R and load the [pm_issues task](pm_issues.py) and the model.

# %%
import actr
import pm_issues

# %% [markdown]
# Run this cell to run a trial of the task in the "next" condition.

# %%
pm_issues.task("next")

# %% [markdown]
# Run this cell to run a trial of the task in the "previous" condition.

# %%
pm_issues.task("previous")
