# %% [markdown]
# # Links to the ACT-R tutorial unit pdfs

# %% [markdown]
# * Unit 1:
#  [main text](./unit1/unit1.pdf)
#  [task code](./unit1/unit1_code.pdf)
#  [additional modeling information](./unit1/unit1_modeling.pdf)
#  [production summary](./unit1/productions-summary.pdf)
# * Unit 2:
#  [main text](./unit2/unit2.pdf)
#  [task code](./unit2/unit2_code.pdf)
#  [production summary](./unit2/productions-summary.pdf)
# * Unit 3:
#  [main text](./unit3/unit3.pdf)
#  [task code](./unit3/unit3_code.pdf)
#  [additional modeling information](./unit3/unit3_modeling.pdf)
#  [production summary](./unit3/productions-summary.pdf)
# * Unit 4:
#  [main text](./unit4/unit4.pdf)
#  [task code](./unit4/unit4_code.pdf)
#  [production summary](./unit4/productions-summary.pdf)
# * Unit 5:
#  [main text](./unit5/unit5.pdf)
#  [task code](./unit5/unit5_code.pdf)
#  [additional modeling information](./unit5/unit5_modeling.pdf)
#  [production summary](./unit5/productions-summary.pdf)
# * Unit 6:
#  [main text](./unit6/unit6.pdf)
#  [task code](./unit6/unit6_code.pdf)
#  [production summary](./unit6/productions-summary.pdf)
# * Unit 7:
#  [main text](./unit7/unit7.pdf)
#  [task code](./unit7/unit7_code.pdf)
#  [additional modeling information](./unit7/unit7_modeling.pdf)
#  [production summary](./unit7/productions-summary.pdf)
# * Unit 8:
#  [main text](./unit8/unit8.pdf)
#  [task code](./unit8/unit8_code.pdf)
#  [production summary](./unit8/productions-summary.pdf)

# %% [markdown]
# # Links to notebooks where you can run the ACT-R tutorial models

# %% [markdown]
# [Unit 1 models](./python/unit1.ipynb)
# [Unit 2 models](./python/unit2.ipynb)
# [Unit 3 models](./python/unit3.ipynb)
# [Unit 4 models](./python/unit4.ipynb)
# [Unit 5 models](./python/unit5.ipynb)
# [Unit 6 models](./python/unit6.ipynb)
# [Unit 7 models](./python/unit7.ipynb)
# [Unit 8 models](./python/unit8.ipynb)
